# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3], [4,5,6]], columns=['A', 'B', 'C'])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.tail(1)
# Out:
#    A  B  C
# 1  4  5  6

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.tolist()
# Out:
# [0, 1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      int64
#  1   B       2 non-null      int64
#  2   C       2 non-null      int64
# dtypes: int64(3)
# memory usage: 180.0 bytes

# %%
df.describe()
# Out:
#              A        B        C
# count  2.00000  2.00000  2.00000
# mean   2.50000  3.50000  4.50000
# std    2.12132  2.12132  2.12132
# min    1.00000  2.00000  3.00000
# 25%    1.75000  2.75000  3.75000
# 50%    2.50000  3.50000  4.50000
# 75%    3.25000  4.25000  5.25000
# max    4.00000  5.00000  6.00000

# %%
df.nunique()
# Out:
# A    2
# B    2
# C    2
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 2

# %%
df.shape
# Out:
# (2, 3)

# %%
coffee_df = pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee_df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee_df)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_df.sample(3)
# Out:
#        Day Coffee Type  Units Sold
# 9   Friday       Latte          35
# 0   Monday    Espresso          25
# 3  Tuesday       Latte          20

# %%
# # coffee_df.loc[#Rows, #Cols]
# # coffee_df.loc[0:1]

# coffee_df.loc[0:10, "Day"]

coffee_df.loc[0:10, ["Day", "Coffee Type"]]
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso

# %%
coffee_df.iloc[:, [0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee_df.index = coffee_df.Day

# %%
coffee_df.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee_df.loc["Monday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %%
coffee_df.loc["Monday" : "Friday", "Units Sold"]
# Out:
# Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Thursday     40
# Thursday     30
# Friday       45
# Friday       35
# Name: Units Sold, dtype: int64

# %%
coffee_df.iloc[:, 2:]
# Out:
#            Units Sold
# Day
# Monday             25
# Monday             15
# Tuesday            30
# Tuesday            20
# Wednesday          35
# Wednesday          25
# Thursday           40
# Thursday           30
# Friday             45
# Friday             35
# Saturday           45
# Saturday           35
# Sunday             45
# Sunday             35

# %%
coffee_df.iloc[1, 2] = 10

# %%
coffee_df
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
coffee_df.at["Monday", "Units Sold"]
# Out:
# Day
# Monday    25
# Monday    10
# Name: Units Sold, dtype: int64

# %%
coffee_df.iat[0, 2]
# Out:
# np.int64(25)

# %%
coffee_df.iloc[0, 2]
# Out:
# np.int64(25)

# %%
coffee_df.Day
# Out:
# Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# Name: Day, dtype: object

# %%
coffee_df.sort_values("Units Sold", ascending=False)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Saturday    Saturday    Espresso          45
# Friday        Friday    Espresso          45
# Sunday        Sunday    Espresso          45
# Thursday    Thursday    Espresso          40
# Wednesday  Wednesday    Espresso          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Friday        Friday       Latte          35
# Tuesday      Tuesday    Espresso          30
# Thursday    Thursday       Latte          30
# Monday        Monday    Espresso          25
# Wednesday  Wednesday       Latte          25
# Tuesday      Tuesday       Latte          20
# Monday        Monday       Latte          10

# %%
coffee_df.sort_values(["Units Sold", "Coffee Type"], ascending=[0, True])
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Friday        Friday    Espresso          45
# Saturday    Saturday    Espresso          45
# Sunday        Sunday    Espresso          45
# Thursday    Thursday    Espresso          40
# Wednesday  Wednesday    Espresso          35
# Friday        Friday       Latte          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Tuesday      Tuesday    Espresso          30
# Thursday    Thursday       Latte          30
# Monday        Monday    Espresso          25
# Wednesday  Wednesday       Latte          25
# Tuesday      Tuesday       Latte          20
# Monday        Monday       Latte          10

# %%
for index, row in coffee_df.iterrows():
    print(index, " row: ", row)
    print("\n\n")
# Out:
# Monday  row:  Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: Monday, dtype: object
#
#
#
# Monday  row:  Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: Monday, dtype: object
#
#
#
# Tuesday  row:  Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: Tuesday, dtype: object
#
#
#
# Tuesday  row:  Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: Tuesday, dtype: object
#
#
#
# Wednesday  row:  Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: Wednesday, dtype: object
#
#
#
# Wednesday  row:  Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: Wednesday, dtype: object
#
#
#
# Thursday  row:  Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: Thursday, dtype: object
#
#
#
# Thursday  row:  Day            Thursday
# Coffee Type       Latte
# ...

# %% [markdown]
# Filtering Rows

# %%
bios = pd.read_csv('./data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.isna().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm        38849
# weight_kg        43430
# died_date       111560
# dtype: int64

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['height_cm'] > 180, ["name", 'born_date', 'born_region']]
# Out:
#                      name   born_date           born_region
# 1          Arnaud Boetsch  1969-04-01              Yvelines
# 2            Jean Borotra  1898-08-13  Pyrénées-Atlantiques
# 5       Nicolas Chatelain  1970-01-13                 Somme
# 16             Guy Forget  1965-01-04     Casablanca-Settat
# 25          Henri Leconte  1963-07-04         Pas-de-Calais
# ...                   ...         ...                   ...
# 145465  Stanislav Galiyev  1992-01-17                Moskva
# 145466     Mikkel Aagaard  1995-10-18           Nordjylland
# 145468  Justin Abdelkader  1987-02-25              Michigan
# 145473     Toms Andersons  1993-11-25                  Rīga
# 145494      George Wright  1890-07-21               Ontario
#
# [35368 rows x 3 columns]

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country']=='USA')][['name', 'NOC']]
# Out:
#                     name            NOC
# 5781      Tommy Burleson  United States
# 6722    Shaquille O'Neal  United States
# 6937      David Robinson  United States
# 123850    Tyson Chandler  United States

# %%
bios[bios['name'].str.contains('Keith', case = False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country'].isin(["USA", "FRA", "GBR"])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 4                5           Albert Canet  1878-04-17     Wandsworth
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
bios.query('born_country == "USA"')
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %% [markdown]
# ### Adding/Removing Columns

# %%
coffee_df.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          10
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee_df['price'] = 4.99

# %%
import numpy as np

# %%
coffee_df['new_price'] = np.where(coffee_df['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
coffee_df.head()
# Out:
#                  Day Coffee Type  Units Sold  price  new_price
# Day
# Monday        Monday    Espresso          25   4.99       3.99
# Monday        Monday       Latte          10   4.99       5.99
# Tuesday      Tuesday    Espresso          30   4.99       3.99
# Tuesday      Tuesday       Latte          20   4.99       5.99
# Wednesday  Wednesday    Espresso          35   4.99       3.99

# %%
coffee_df.drop(columns=['price'])
coffee_df
# Out:
#                  Day Coffee Type  Units Sold  price  new_price
# Day
# Monday        Monday    Espresso          25   4.99       3.99
# Monday        Monday       Latte          10   4.99       5.99
# Tuesday      Tuesday    Espresso          30   4.99       3.99
# Tuesday      Tuesday       Latte          20   4.99       5.99
# Wednesday  Wednesday    Espresso          35   4.99       3.99
# Wednesday  Wednesday       Latte          25   4.99       5.99
# Thursday    Thursday    Espresso          40   4.99       3.99
# Thursday    Thursday       Latte          30   4.99       5.99
# Friday        Friday    Espresso          45   4.99       3.99
# Friday        Friday       Latte          35   4.99       5.99
# Saturday    Saturday    Espresso          45   4.99       3.99
# Saturday    Saturday       Latte          35   4.99       5.99
# Sunday        Sunday    Espresso          45   4.99       3.99
# Sunday        Sunday       Latte          35   4.99       5.99

# %%
# coffee_df.drop(columns=['price'], inplace = True)
coffee_df
# Out:
#                  Day Coffee Type  Units Sold  new_price
# Day
# Monday        Monday    Espresso          25       3.99
# Monday        Monday       Latte          10       5.99
# Tuesday      Tuesday    Espresso          30       3.99
# Tuesday      Tuesday       Latte          20       5.99
# Wednesday  Wednesday    Espresso          35       3.99
# Wednesday  Wednesday       Latte          25       5.99
# Thursday    Thursday    Espresso          40       3.99
# Thursday    Thursday       Latte          30       5.99
# Friday        Friday    Espresso          45       3.99
# Friday        Friday       Latte          35       5.99
# Saturday    Saturday    Espresso          45       3.99
# Saturday    Saturday       Latte          35       5.99
# Sunday        Sunday    Espresso          45       3.99
# Sunday        Sunday       Latte          35       5.99

# %%
coffee_df.drop(columns = 'Day', inplace = True)

# %%
coffee_df['revenue'] = coffee_df['Units Sold'] * coffee_df['new_price']

# %%
coffee_df.head()
# Out:
#           Coffee Type  Units Sold  new_price  revenue
# Day
# Monday       Espresso          25       3.99    99.75
# Monday          Latte          10       5.99    59.90
# Tuesday      Espresso          30       3.99   119.70
# Tuesday         Latte          20       5.99   119.80
# Wednesday    Espresso          35       3.99   139.65

# %%
coffee_df.rename(columns = {'new_price' : 'price'}, inplace = True)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
pd.to_datetime(bios_new['born_date']).info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 145500 entries, 0 to 145499
# Series name: born_date
# Non-Null Count   Dtype
# --------------   -----
# 143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.1 MB

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime
# 0  1960-10-02  Jean-François    1886-12-12
# 1         NaN         Arnaud    1969-04-01
# 2  1994-07-17           Jean    1898-08-13
# ...

# %%
bios_new['born_datetime'].dt.year
# Out:
# 0         1886.0
# 1         1969.0
# 2         1898.0
# 3         1895.0
# 4         1878.0
#            ...
# 145495    2002.0
# 145496    1999.0
# 145497    1998.0
# 145498    1899.0
# 145499    1913.0
# Name: born_datetime, Length: 145500, dtype: float64

# %%
bios_new['born_datetime'].dt.year.fillna(0).astype(int)
# Out:
# 0         1886
# 1         1969
# 2         1898
# 3         1895
# 4         1878
#           ...
# 145495    2002
# 145496    1999
# 145497    1998
# 145498    1899
# 145499    1913
# Name: born_datetime, Length: 145500, dtype: int64

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year.fillna(0).astype(int)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12       1886
# 1         NaN         Arnaud    1969-04-01       1969
# ...

# %%
bios_new['height_category'] = bios_new['height_cm'].apply(lambda x : 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year height_category
# 0  1960-10-02  Jean-François    1886-12-12       1886            Tall
# ...

# %% [markdown]
# ### Merging and Concat

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new_merged = pd.merge(bios, nocs, left_on = 'born_country', right_on = 'NOC', how = 'left')

# %%
bios_new_merged.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
pd.merge(bios, nocs, left_on = 'born_country', right_on = 'NOC', how = 'right')
# Out:
#         athlete_id                  name   born_date    born_city born_region  \
# 0          57056.0     Mohammad Ebrahimi  1930-04-11        Kabul       Kabul
# 1          57062.0            Kayum Ayub  1947-06-21        Kabul       Kabul
# 2          57064.0    Aka-Jahan Dastagir  1946-06-05        Kabul       Kabul
# 3          57065.0       Ghulam Dastagir  1945-07-24        Kabul       Kabul
# 4          57066.0            Ahmad Djan  1948-02-10        Kabul       Kabul
# ...            ...                   ...         ...          ...         ...
# 110661    147637.0          Donata Katai  2004-05-07       Harare      Harare
# 110662    147638.0         Ngoni Makusha  1994-06-29  Chitungwiza      Harare
# 110663    147639.0         Scott Vincent  1992-05-20       Harare      Harare
# 110664    147640.0  Peter Purcell-Gilpin  1994-07-04       Harare      Harare
# 110665    147641.0         Peter Wetzlar  1997-02-27       Harare      Harare
#
# ...

# %%
bios_new_merged.rename({'region' : 'born_country_full'}, inplace = True)

# %%
usa = bios[bios['born_country']=='USA'].copy()
gbr = bios[bios['born_country']=='GBR'].copy()

# %%
new_df = pd.concat([usa, gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN

# %%
coffee_df.isna().sum()
# Out:
# Coffee Type    0
# Units Sold     0
# price          0
# revenue        0
# dtype: int64

# %%
coffee_df[]
# Out:
#           Coffee Type  Units Sold  price  revenue
# Day
# Monday       Espresso          25   3.99    99.75
# Monday          Latte          10   5.99    59.90
# Tuesday      Espresso          30   3.99   119.70
# Tuesday         Latte          20   5.99   119.80
# Wednesday    Espresso          35   3.99   139.65
# Wednesday       Latte          25   5.99   149.75
# Thursday     Espresso          40   3.99   159.60
# Thursday        Latte          30   5.99   179.70
# Friday       Espresso          45   3.99   179.55
# Friday          Latte          35   5.99   209.65
# Saturday     Espresso          45   3.99   179.55
# Saturday        Latte          35   5.99   209.65
# Sunday       Espresso          45   3.99   179.55
# Sunday          Latte          35   5.99   209.65

# %% [markdown]
# ### Aggregation

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Kirovgrad             1
# Pereiaslav            1
# Podgornyy             1
# Kudepsta              1
# Furmanov              1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] =='USA']['born_region'].value_counts().head()
# Out:
# born_region
# California       1634
# New York          990
# Illinois          585
# Massachusetts     530
# Pennsylvania      530
# Name: count, dtype: int64

# %%
coffee_df.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       190
# Name: Units Sold, dtype: int64

# %%
coffee_df.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.142857
# Name: Units Sold, dtype: float64

# %%
coffee_df.groupby(['Coffee Type', 'Day']).agg({'Units Sold' : 'sum', 'price' : 'mean'})
# Out:
#                        Units Sold  price
# Coffee Type Day
# Espresso    Friday             45   3.99
#             Monday             25   3.99
#             Saturday           45   3.99
#             Sunday             45   3.99
#             Thursday           40   3.99
#             Tuesday            30   3.99
#             Wednesday          35   3.99
# Latte       Friday             35   5.99
#             Monday             10   5.99
#             Saturday           35   5.99
#             Sunday             35   5.99
#             Thursday           30   5.99
#             Tuesday            20   5.99
#             Wednesday          25   5.99

# %% [markdown]
# ### Pivot Tables

# %%
pivot = coffee_df.pivot(columns='Coffee Type', values='revenue')

# %%
pivot.head()
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   59.90
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1138.10
# dtype: float64

# %%
pivot.sum(axis = 1)
# Out:
# Day
# Friday       389.20
# Monday       159.65
# Saturday     389.20
# Sunday       389.20
# Thursday     339.30
# Tuesday      239.50
# Wednesday    289.40
# dtype: float64

# %%
bios.groupby(bios['born_date'].dt.year)['name'].count()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Jitto\Documents\Code\AICoding\aicoding\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jitto\AppData\Local\Temp\ipykernel_29592\1771076168.py", line 1, in <module>
#     bios.groupby(bios['born_date'].dt.year)['name'].count()
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jitto\Documents\Code\AICoding\aicoding\Lib\site-packages\pandas\core\generic.py", line 6321, in __getattr__
#     return object.__getattribute__(self, name)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\Jitto\Documents\Code\AICoding\aicoding\Lib\site-packages\pandas\core\accessor.py", line 224, in __get__
#     accessor_obj = self._accessor(obj)
# ...
